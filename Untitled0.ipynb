# %% [markdown]
# <a href="https://colab.research.google.com/github/EngenBD2025/engenhariadedados/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Bibliotecas para manipulação de dados
import pandas as pd          # Manipulação de tabelas (DataFrames)
import numpy as np           # Cálculos numéricos, útil para vetores e arrays
from pyspark.sql import SparkSession
from sqlalchemy import create_engine

# Bibliotecas para visualização de dados
import matplotlib.pyplot as plt     # Gráficos estáticos (linhas, barras, pizza, etc.)
import seaborn as sns               # Visualizações estatísticas avançadas com base no matplotlib

# Opcional: Estilização de gráficos
plt.style.use('seaborn-v0_8-darkgrid')  # Estilo de gráfico (opcional)

# Configurações adicionais (opcional)
import warnings
warnings.filterwarnings("ignore")  # Ignora avisos para manter a saída limpa


# Verificando versões (útil para compatibilidade)
print("Versões das bibliotecas:")
print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("matplotlib:", plt.matplotlib.__version__)
print("seaborn:", sns.__version__)
# Out:
# Versões das bibliotecas:
# pandas: 2.2.2
# numpy: 2.0.2
# matplotlib: 3.10.0
# seaborn: 0.13.2

# %%
import os

# ======================= ETAPA 2: INSTALAR SPARK 3.5.5 ===========================
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://downloads.apache.org/spark/spark-3.5.5/spark-3.5.5-bin-hadoop3.tgz
# !tar -xzf spark-3.5.5-bin-hadoop3.tgz
# !pip install -q findspark

# ======================= ETAPA 3: CONFIGURAR E INICIAR SPARK ===========================

from pyspark.sql import SparkSession
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.classification import DecisionTreeClassifier
from pyspark.ml import Pipeline

# 🚀 Instalar PySpark
# !pip install pyspark -q

# 🧠 Imports
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, avg, datediff, to_date
# Out:
# tar (child): spark-3.5.5-bin-hadoop3.tgz: Cannot open: No such file or directory
# tar (child): Error is not recoverable: exiting now
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now

# %%
file_path = '/content/relatorio_final.csv'  # Substitua pelo caminho correto

# %%
# Importando bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Caminho do arquivo CSV
file_path = '/content/relatorio_final.csv'  # Substitua pelo caminho correto

# Leitura do arquivo CSV
df = pd.read_csv(file_path)

# Configuração para visualização mais limpa
plt.style.use('seaborn-v0_8-darkgrid')

# 1. Quantidade de vendas por categoria de serviço
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='categoria_servico', order=df['categoria_servico'].value_counts().index, palette='viridis')
plt.title('Quantidade de Vendas por Categoria de Serviço')
plt.xlabel('Categoria de Serviço')
plt.ylabel('Quantidade de Vendas')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 2. Receita total por serviço
df['receita_total'] = df['quantidade'] * df['preco_unitario']
receita_por_servico = df.groupby('servico')['receita_total'].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
receita_por_servico.plot(kind='bar', color='skyblue')
plt.title('Receita Total por Serviço')
plt.xlabel('Serviço')
plt.ylabel('Receita Total (R$)')
plt.tight_layout()
plt.show()

# 3. Distribuição das vendas por região
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='regiao', palette='pastel', order=df['regiao'].value_counts(85).index)
plt.title('Distribuição das Vendas por Região')
plt.xlabel('Região')
plt.ylabel('Quantidade de Vendas')
plt.tight_layout()
plt.show()

# 4. Relação entre custo e receita total
plt.figure(figsize=(8, 4))
sns.scatterplot(data=df, x='custo', y='receita_total', hue='regiao', palette='Set2')
plt.title('Relação entre Custo e Receita Total')
plt.xlabel('Custo (R$)')
plt.ylabel('Receita Total (R$)')
plt.tight_layout()
plt.show()

# 5. Receita total por estado
receita_por_estado = df.groupby('estado')['receita_total'].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
receita_por_estado.plot(kind='bar', color='orange')
plt.title('Receita Total por Estado')
plt.xlabel('Estado')
plt.ylabel('Receita Total (R$)')
plt.tight_layout()
plt.show()
